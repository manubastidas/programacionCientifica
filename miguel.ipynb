# %% [markdown]
# ## Quiénes Somos y desde dónde
#
# - **Nombre:** Miguel Fonseca
# - **Fecha y hora:** 24/04/2026 2:45 p.m.
#
# ---
#
# # Curvas de Lissajous
# ### Programación Científica 2026-1 · Universidad Nacional de Colombia
#
# Una curva de Lissajous describe el movimiento de un punto sometido a dos oscilaciones armónicas perpendiculares:
#
# $$x(t) = A \sin(a t + \delta)$$
# $$y(t) = B \sin(b t)$$
#
# La forma de la curva depende de la relación $a/b$ y del desfase $\delta$.
#
# ## Segundo comentario
#
# Este código genera una visualización de curvas de Lissajous usando funciones sinusoidales.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# ── PARÁMETROS — modifica estos valores ─────────────────────────

a     = 3          # frecuencia en x
b     = 2          # frecuencia en y
delta = np.pi / 4  # desfase en radianes

A     = 1.0        # amplitud en x
B     = 1.0        # amplitud en y

COLOR = "#e63946"  # color de la curva
FONDO = "#0d1117"  # color de fondo

GROSOR = 1.8
ALPHA  = 0.85

# %%
t = np.linspace(0, 2 * np.pi, 4000)
x = A * np.sin(a * t + delta)
y = B * np.sin(b * t)

fig, ax = plt.subplots(figsize=(5, 5), dpi=150)
fig.patch.set_facecolor(FONDO)
ax.set_facecolor(FONDO)

ax.plot(x, y, color=COLOR, lw=GROSOR, alpha=ALPHA, solid_capstyle="round")

ax.set_aspect("equal")
ax.axis("off")

fig.tight_layout(pad=0.3)
plt.show()

# %%
# Guardar la imagen
NOMBRE_ARCHIVO = "miguel_fonseca"

fig.savefig(f"{NOMBRE_ARCHIVO}.jpg", dpi=150,
            facecolor=fig.get_facecolor(), bbox_inches="tight")

print(f"Guardado: {NOMBRE_ARCHIVO}.jpg")
